# %% [markdown]
# # **Time-Series Forecasting**
# #### *Case Study: Gold Prices Prediction*
#
# ![DALL·E 2024-09-27 19.37.40 - A wide isometric image of a financial data dashboard focused on Gold Prediction Time Forecasting. The design uses a golden color scheme with highlight.webp](<attachment:DALL·E 2024-09-27 19.37.40 - A wide isometric image of a financial data dashboard focused on Gold Prediction Time Forecasting. The design uses a golden color scheme with highlight.webp>)
#
# ##### Data Scientist:
# 1. Zacharia Bachtiar
# 2. Zia Tabaruq
# 3. Fachmi Aditya

# %% [markdown]
# ## **Business Problem Understanding**
# ### **Context**
# Perusahaan melacak harga emas bulanan, yang berfluktuasi berdasarkan berbagai faktor ekonomi, tren pasar, dan peristiwa geopolitik. Emas adalah aset investasi dan cadangan yang signifikan bagi banyak industri, pemerintah, dan investor. Perkiraan harga emas yang akurat sangat penting untuk perencanaan keuangan, strategi investasi, dan manajemen risiko.
#
# ### **Problem Statement**
# Perusahaan perlu memprediksi harga emas di masa depan dengan menggunakan data historis bulanan. Tujuannya adalah untuk mengimplementasikan dan menyetel model peramalan deret waktu (ARIMA, SARIMA, dan Prophet) untuk mencapai prediksi yang paling akurat. Dengan membandingkan kinerja model-model ini, perusahaan bertujuan untuk memilih model yang paling efektif untuk meramalkan harga emas di masa depan.
#
# ### **Goals**
# - Memprediksi harga emas bulanan untuk periode mendatang berdasarkan data historis.
# - Bandingkan akurasi peramalan model ARIMA, SARIMA, dan Prophet.
# - Gunakan tuning hyperparameter untuk mengoptimalkan setiap model untuk performa yang lebih baik.
#
# ### **Analytic Approach**
# 1. **Data Preparation**: Siapkan data harga emas historis dengan mengatur Tanggal sebagai indeks dan Harga sebagai variabel target.
# 2. **Model Selection**:
#    - Menerapkan model ARIMA, SARIMA, dan Prophet.
#    - Melakukan tuning hiperparameter menggunakan validasi silang deret waktu untuk setiap model.
# 3. **Forecasting**: Menghasilkan prakiraan harga di masa depan dengan menggunakan model yang telah dilatih.
# 4. **Comparison**: Bandingkan hasil perkiraan berdasarkan metrik RMSE.
#
# ### **Metric Evaluation**
# - **Root Mean Squared Error (RMSE)**: Metrik ini akan digunakan untuk mengevaluasi akurasi peramalan. RMSE yang lebih rendah mengindikasikan model yang lebih akurat. Tujuannya adalah untuk meminimalkan RMSE dan memilih model dengan performa peramalan terbaik untuk harga emas.

# %% [markdown]
# ## **Data Understanding**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.graph_objects as go

from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from prophet import Prophet

from sklearn.metrics import mean_squared_error, root_mean_squared_error, mean_absolute_error
import warnings

# Suppress warnings for cleaner output
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('monthly.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    825 non-null    object
#  1   Price   825 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 13.0+ KB

# %%
display(df['Date'].min(), df['Date'].max())
# Out:
# '1950-01'
# '2018-09'

# %%
df[['Price']].describe()
# Out:
#              Price
# count   825.000000
# mean    388.730868
# std     424.991665
# min      34.490000
# 25%      35.190000
# 50%     310.045000
# 75%     429.140000
# max    1780.648000

# %% [markdown]
# > Catatan:
# >
# > - **Periode Waktu**:
# >   - Dataset berisi harga emas dari**January 1950 to September 2018** dengan entri bulanan.
# > - **Fitur**: Fitur-fitur utama meliputi:
# >   - `Date`: Tanggal pengamatan.
# >   - `Price`: Harga penutupan emas, yang akan digunakan sebagai target untuk peramalan.
# > - **Ringkasan Statistik**:
# >    - Rata-rata `Price` from 1950 - 2018 adalah **388.73**.
# >  - **Standar Deviasi**:
# >    - Data cukup fluktuatif, dengan deviasi standar untuk `Price` **424.99**, menunjukkan fluktuasi besar dalam harga emas dari waktu ke waktu.
# >  - **Pengamatan Utama**:
# >    - Data menunjukkan bahwa harga emas menunjukkan volatilitas yang tinggi dan fluktuasi yang besar, sehingga perkiraan yang akurat sangat penting untuk pengambilan keputusan.

# %% [markdown]
# ## **Data Preparation**

# %% [markdown]
# #### **Convert Date Feature**

# %%
# Sorting the data by Date for time series continuity
df = df[['Date','Price']].sort_values('Date')
df.head(10)
# Out:
#       Date  Price
# 0  1950-01  34.73
# 1  1950-02  34.73
# 2  1950-03  34.73
# 3  1950-04  34.73
# 4  1950-05  34.73
# 5  1950-06  34.73
# 6  1950-07  34.73
# 7  1950-08  34.73
# 8  1950-09  34.73
# 9  1950-10  34.73

# %% [markdown]
# > Catatan:
# > - Ubah tipe data `Date` menjadi datetime untuk analisis berbasis waktu yang lebih akurat.

# %% [markdown]
# #### **Handle Missing Values**

# %%
missing_values = df.isnull().sum()

missing_values
# Out:
# Date     0
# Price    0
# dtype: int64

# %% [markdown]
# > Catatan:
# > - Dataset bersih dari nilai yang hilang.

# %% [markdown]
# ## **Data Analysis**

# %% [markdown]
# #### **Overall Trend**

# %%
import matplotlib.dates as mdates


plt.figure(figsize=(30,15))
sns.set_context(context='notebook', font_scale=2)
sns.lineplot(x='Date', y='Price', data=df)

plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))

plt.xticks(rotation=45)
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# > Catatan:
# >
# > - **1950 hingga 1970**: Harga-harga tetap relatif datar, menunjukkan stabilitas.
# > - **1970 hingga 1980**: Lonjakan harga yang signifikan, kemungkinan disebabkan oleh peristiwa ekonomi (misalnya, penghapusan standar emas).
# > - **1980 hingga 2000**: Tren menurun dan stabil, dengan fluktuasi kecil.
# > - **2000 hingga 2011**: Kenaikan harga emas yang dramatis, mencapai titik tertinggi sepanjang sejarah pada tahun 2011.
# > - **2011 hingga 2018**: Harga turun dan stabil dengan fluktuasi moderat, tetapi tetap lebih tinggi dibandingkan dengan dekade sebelumnya.

# %% [markdown]
# ## **Modeling and Evaluation**

# %% [markdown]
# #### **Split Data**

# %%
df = df[df['Date']>'2003-01']
df_train=df[(df['Date']>'2006-01') & (df['Date']<='2013-05')]
df_test=df[df['Date']>'2013-05']

display(len(df_train),len(df_test))
# Out:
# 88
# 64

# %% [markdown]
# > Catatan:
# >
# > - Dataset dibagi menjadi set pelatihan dan set pengujian untuk menghindari kebocoran data.
# > - **Training Data**: Menggunakan data **7 tahun** terbaru karena perbedaan tren harga emas (kami ingin tren terbaru dan relevan untuk memperkirakan tren masa depan).
# > - **Test Data**: Data **5 tahun terakhir** digunakan untuk evaluasi dan peramalan.

# %% [markdown]
# #### **ARIMA**

# %%
import itertools
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

p = q = range(0, 10)
d = 1

pdq = [(x, d, y) for x, y in itertools.product(p, q)]

results = []

for param in pdq:
    try:
        model = ARIMA(df_train['Price'], order=param)

        model_fit = model.fit()

        forecast_steps = len(df_test)
        arima_forecast = model_fit.forecast(steps=forecast_steps)

        arima_rmse = mean_squared_error(df_test['Price'], arima_forecast, squared=False)

        results.append((param, arima_rmse))

    except Exception as e:
        continue

# Sort the results based on RMSE in descending order
sorted_results = sorted(results, key=lambda x: x[1], reverse=False)

sorted_results = pd.DataFrame(sorted_results).sort_values(1, ascending=True).rename({0:'order', 1:'rmse'}, axis=1)
sorted_results.head()
# Out:
#        order       rmse
# 0  (6, 1, 9)  66.695779
# 1  (8, 1, 3)  75.847935
# 2  (1, 1, 5)  83.092172
# 3  (3, 1, 2)  83.233876
# 4  (2, 1, 3)  83.666796

# %% [markdown]
# > Catatan:
# >
# > - Model ARIMA disetel dengan melakukan **pencarian grid** pada nilai yang berbeda dari \( p \), \( d \), dan \( q \).
# > - **Parameter Non-Musiman**:
# > - \( p \): Jumlah pengamatan lag.
# > - \( d \): Jumlah perbedaan yang diperlukan untuk membuat deret waktu menjadi stasioner (diatur ke 1 dalam kasus ini).
# > - \( q \): Ukuran jendela rata-rata bergerak.
# > - **Strategi Penyetelan**:
# > - Pencarian grid pada kombinasi \( p \) dan \( q \) (mulai dari 0 hingga 9) dilakukan dengan \( d \) ditetapkan pada 1.
# > - RMSE (Root Mean Squared Error) dihitung untuk setiap kombinasi, dan model dengan kinerja terbaik dipilih berdasarkan nilai RMSE terendah.
# > - **Hasil**: Hasil disimpan, diurutkan, dan ditampilkan, sehingga urutan model ARIMA terbaik (dengan RMSE terendah) dapat dipilih untuk meramalkan tren masa depan.

# %%
from statsmodels.tsa.arima.model import ARIMA
model=ARIMA(df_train['Price'],order=sorted_results.iloc[0]['order'])

model_fit=model.fit()

forecast_length=64
forecast_result=model_fit.forecast(forecast_length)

root_mean_squared_error(df_test['Price'], forecast_result)
# Out:
# 66.69577937306198

# %%
month=list(df_test['Date'].unique())

df_forecast_arima=pd.DataFrame({'Date':month,'Price':forecast_result})
df_forecast_arima
# Out:
#         Date        Price
# 88   2013-06  1416.343017
# 89   2013-07  1420.663928
# 90   2013-08  1393.574069
# 91   2013-09  1374.654830
# 92   2013-10  1364.360960
# ..       ...          ...
# 147  2018-05  1220.074973
# 148  2018-06  1233.855530
# 149  2018-07  1239.096778
# 150  2018-08  1226.103187
# 151  2018-09  1209.740947
#
# [64 rows x 2 columns]

# %%
import plotly.graph_objects as go

fig = go.Figure([go.Scatter(name='Actual', x=df['Date'], y=df['Price'], mode='markers')])

fig.add_trace(go.Scatter(name='Forecast', x=df_forecast_arima['Date'], y=df_forecast_arima['Price']))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="85751a91-e348-476c-9ff2-e1fb950c3a49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85751a91-e348-476c-9ff2-e1fb950c3a49")) {                    Plotly.newPlot(                        "85751a91-e348-476c-9ff2-e1fb950c3a49",                        [{"mode":"markers","name":"Actual","x":["2003-02","2003-03","2003-04","2003-05","2003-06","2003-07","2003-08","2003-09","2003-10","2003-11","2003-12","2004-01","2004-02","2004-03","2004-04","2004-05","2004-06","2004-07","2004-08","2004-09","2004-10","2004-11","2004-12","2005-01","2005-02","2005-03","2005-04","2005-05","2005-06","2005-07","2005-08","2005-09","2005-10","2005-11","2005-12","2006-01","2006-02","2006-03","2006-04","2006-05","2006-06","2006-07","2006-08","2006-09","2006-10","2006-11","2006-12","2007-01","2007-02","2007-03","2007-04","2007-05","2007-06","2007-07","2007-08","2007-09","2007-10","2007-11","2007-12","2008-01","2008-02","2008-03","2008-04","2008-05","2008-06","2008-07","2008-08","2008-09","2008-10","2008-11","2008-12","2009-01","2009-02","2009-03","2009-04","2009-05","2009-06","2009-07","2009-08","2009-09","2009-10","2009-11","2009-12","2010-01","2010-02","2010-03","2010-04","2010-05","2010-06","2010-07","2010-08","2010-09","2010-10","2010-11","2010-12","2011-01","2011-02","2011-03","2011-04","2011-05","2011-06","2011-07","2011-08","2011-09","2011-10","2011-11","2011-12","2012-01","2012-02","2012-03","2012-04","2012-05","2012-06","2012-07","2012-08","2012-09","2012-10","2012-11","2012-12","2013-01","2013-02","2013-03","2013-04","2013-05","2013-06","2013-07","2013-08","2013-09","2013-10","2013-11","2013-12","2014-01","2014-02","2014-03","2014-04","2014-05","2014-06","2014-07","2014-08","2014-09","2014-10","2014-11","2014-12","2015-01","2015-02","2015-03","2015-04","2015-05","2015-06","2015-07","2015-08","2015-09","2015-10","2015-11","2015-12","2016-01","2016-02","2016-03","2016-04","2016-05","2016-06","2016-07","2016-08","2016-09","2016-10","2016-11","2016-12","2017-01","2017-02","2017-03","2017-04","2017-05","2017-06","2017-07","2017-08","2017-09","2017-10","2017-11","2017-12","2018-01","2018-02","2018-03","2018-04","2018-05","2018-06","2018-07","2018-08","2018-09"],"y":[359.575,341.564,328.208,355.405,356.912,350.765,358.993,378.859,379.093,390.2,407.674,414.495,404.73,405.976,404.85,383.953,391.78,398.441,400.133,405.402,420.21,439.059,442.974,424.08,423.43,434.355,429.14,422.903,430.302,424.745,437.773,455.936,470.107,476.668,509.423,549.433,555.518,557.215,611.853,676.769,597.898,633.093,631.557,600.15,586.648,626.825,629.513,630.352,665.103,655.891,680.008,668.31,655.714,665.266,664.53,710.645,754.48,808.311,803.618,887.784,924.283,971.055,911.6,889.125,889.536,941.167,840.388,824.92,812.815,757.85,819.94,857.726,939.763,925.989,892.663,926.855,947.807,934.272,949.5,996.443,1043.511,1126.119,1135.012,1119.575,1095.8,1115.554,1148.475,1204.321,1232.382,1196.0,1213.464,1271.461,1343.19,1371.784,1393.512,1360.475,1371.313,1422.848,1474.431,1512.188,1528.38,1568.526,1759.5,1780.648,1667.893,1735.977,1652.725,1656.095,1743.095,1675.057,1648.539,1585.114,1595.632,1592.784,1625.682,1741.925,1746.348,1724.352,1687.342,1671.886,1630.688,1591.013,1485.905,1416.143,1342.7,1284.348,1345.048,1348.464,1314.402,1277.417,1221.588,1243.068,1298.713,1336.56,1299.175,1288.913,1277.857,1312.989,1297.005,1241.33,1223.565,1176.413,1200.44,1249.333,1231.1,1180.636,1198.253,1197.684,1182.248,1131.58,1117.525,1124.905,1157.123,1088.388,1068.317,1095.655,1194.893,1246.312,1241.452,1259.755,1273.58,1337.429,1340.861,1326.618,1268.929,1240.293,1152.165,1192.648,1233.39,1231.063,1267.15,1245.25,1261.277,1235.1,1281.72,1317.045,1280.677,1283.189,1265.674,1332.809,1333.775,1325. ...

# %% [markdown]
# > Catatan:
# >
# > - **Strategi Penyetelan**: Kami menetapkan \( d = 1 \) (urutan pembedaan) dan melakukan pencarian grid pada nilai \( p \) dan \( q \) (kisaran 0 hingga 10) untuk menemukan model terbaik menggunakan RMSE (root mean squared error).
# >
# > - **Pemilihan Model Terbaik**: Model dengan RMSE terendah dipilih sebagai model ARIMA terbaik untuk peramalan dengan orde (6, 1, 9).
# >
# > - **Evaluasi**: Model ARIMA terpilih digunakan untuk meramalkan 64 bulan ke depan, dan keakuratannya dievaluasi dengan menggunakan RMSE pada data uji dengan nilai **65,9**.

# %% [markdown]
# #### **SARIMA**

# %%
import itertools

p = q = range(0, 5)
d = 1
P = Q = range(0, 2)
D = 1
s = 12

pdq = [(x, d, y) for x, y in itertools.product(p, q)]
seasonal_pdq = [(x, D, y, s) for x, y in itertools.product(P, Q)]

results = []

for param in pdq:
    for seasonal_param in seasonal_pdq:
        try:
            model = SARIMAX(df_train['Price'], order=param, seasonal_order=seasonal_param)

            model_fit = model.fit(disp=False)

            forecast_steps = len(df_test)
            sarima_forecast = model_fit.forecast(steps=forecast_steps)

            sarima_rmse = mean_squared_error(df_test['Price'], sarima_forecast, squared=False)

            results.append((param, seasonal_param, sarima_rmse))

        except Exception as e:
            continue

# Convert the results to a DataFrame and sort based on RMSE in ascending order
sorted_results = pd.DataFrame(results, columns=['order', 'seasonal_order', 'rmse']).sort_values('rmse', ascending=True)

sorted_results.head()
# Out:
#         order seasonal_order        rmse
# 6   (0, 1, 1)  (1, 1, 0, 12)  191.513035
# 22  (1, 1, 0)  (1, 1, 0, 12)  191.641958
# 2   (0, 1, 0)  (1, 1, 0, 12)  192.352175
# 98  (4, 1, 4)  (1, 1, 0, 12)  194.627772
# 50  (2, 1, 2)  (1, 1, 0, 12)  194.758375

# %% [markdown]
# > Catatan:
# >
# > - **Penyiapan Model**: SARIMA memperluas ARIMA dengan memasukkan parameter non-musiman \((p, d, q) \) dan parameter musiman \((P, D, Q, s) \) untuk menangkap pola musiman. Kami menggunakan pencarian grid untuk menguji berbagai kombinasi parameter ini.
# >
# > - **Evaluasi**: Setiap kombinasi parameter dievaluasi menggunakan **RMSE** pada data uji. Model dengan RMSE terendah dipilih sebagai model dengan kinerja terbaik.
# >
# > - **Perbedaan Utama dari ARIMA**: Tidak seperti ARIMA, SARIMA memperhitungkan **musiman** dengan menambahkan istilah musiman \((P, D, Q, s) \), yang membantu memodelkan pola siklus yang berulang dalam periode yang tetap (seperti tren bulanan).

# %%
model=SARIMAX(df_train['Price'],order=sorted_results.iloc[0]['order'], seasonal_order=sorted_results.iloc[0]['seasonal_order'])

model_fit=model.fit()

forecast_length=64
forecast_result=model_fit.forecast(forecast_length)

root_mean_squared_error(df_test['Price'], forecast_result)
# Out:
# 191.51303459889044

# %%
month=list(df_test['Date'].unique())

df_forecast_sarima=pd.DataFrame({'Date':month,'Price':forecast_result})
df_forecast_sarima
# Out:
#         Date        Price
# 88   2013-06  1423.028475
# 89   2013-07  1442.197902
# 90   2013-08  1556.047353
# 91   2013-09  1623.591763
# 92   2013-10  1568.007367
# ..       ...          ...
# 147  2018-05   986.491049
# 148  2018-06   994.650080
# 149  2018-07  1006.100237
# 150  2018-08  1091.568257
# 151  2018-09  1176.186304
#
# [64 rows x 2 columns]

# %%
import plotly.graph_objects as go

fig = go.Figure([go.Scatter(name='Actual', x=df['Date'], y=df['Price'], mode='markers')])

fig.add_trace(go.Scatter(name='Forecast', x=df_forecast_sarima['Date'], y=df_forecast_sarima['Price']))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4eb7eb26-36b5-4977-98d8-b38509e7c49b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4eb7eb26-36b5-4977-98d8-b38509e7c49b")) {                    Plotly.newPlot(                        "4eb7eb26-36b5-4977-98d8-b38509e7c49b",                        [{"mode":"markers","name":"Actual","x":["2003-02","2003-03","2003-04","2003-05","2003-06","2003-07","2003-08","2003-09","2003-10","2003-11","2003-12","2004-01","2004-02","2004-03","2004-04","2004-05","2004-06","2004-07","2004-08","2004-09","2004-10","2004-11","2004-12","2005-01","2005-02","2005-03","2005-04","2005-05","2005-06","2005-07","2005-08","2005-09","2005-10","2005-11","2005-12","2006-01","2006-02","2006-03","2006-04","2006-05","2006-06","2006-07","2006-08","2006-09","2006-10","2006-11","2006-12","2007-01","2007-02","2007-03","2007-04","2007-05","2007-06","2007-07","2007-08","2007-09","2007-10","2007-11","2007-12","2008-01","2008-02","2008-03","2008-04","2008-05","2008-06","2008-07","2008-08","2008-09","2008-10","2008-11","2008-12","2009-01","2009-02","2009-03","2009-04","2009-05","2009-06","2009-07","2009-08","2009-09","2009-10","2009-11","2009-12","2010-01","2010-02","2010-03","2010-04","2010-05","2010-06","2010-07","2010-08","2010-09","2010-10","2010-11","2010-12","2011-01","2011-02","2011-03","2011-04","2011-05","2011-06","2011-07","2011-08","2011-09","2011-10","2011-11","2011-12","2012-01","2012-02","2012-03","2012-04","2012-05","2012-06","2012-07","2012-08","2012-09","2012-10","2012-11","2012-12","2013-01","2013-02","2013-03","2013-04","2013-05","2013-06","2013-07","2013-08","2013-09","2013-10","2013-11","2013-12","2014-01","2014-02","2014-03","2014-04","2014-05","2014-06","2014-07","2014-08","2014-09","2014-10","2014-11","2014-12","2015-01","2015-02","2015-03","2015-04","2015-05","2015-06","2015-07","2015-08","2015-09","2015-10","2015-11","2015-12","2016-01","2016-02","2016-03","2016-04","2016-05","2016-06","2016-07","2016-08","2016-09","2016-10","2016-11","2016-12","2017-01","2017-02","2017-03","2017-04","2017-05","2017-06","2017-07","2017-08","2017-09","2017-10","2017-11","2017-12","2018-01","2018-02","2018-03","2018-04","2018-05","2018-06","2018-07","2018-08","2018-09"],"y":[359.575,341.564,328.208,355.405,356.912,350.765,358.993,378.859,379.093,390.2,407.674,414.495,404.73,405.976,404.85,383.953,391.78,398.441,400.133,405.402,420.21,439.059,442.974,424.08,423.43,434.355,429.14,422.903,430.302,424.745,437.773,455.936,470.107,476.668,509.423,549.433,555.518,557.215,611.853,676.769,597.898,633.093,631.557,600.15,586.648,626.825,629.513,630.352,665.103,655.891,680.008,668.31,655.714,665.266,664.53,710.645,754.48,808.311,803.618,887.784,924.283,971.055,911.6,889.125,889.536,941.167,840.388,824.92,812.815,757.85,819.94,857.726,939.763,925.989,892.663,926.855,947.807,934.272,949.5,996.443,1043.511,1126.119,1135.012,1119.575,1095.8,1115.554,1148.475,1204.321,1232.382,1196.0,1213.464,1271.461,1343.19,1371.784,1393.512,1360.475,1371.313,1422.848,1474.431,1512.188,1528.38,1568.526,1759.5,1780.648,1667.893,1735.977,1652.725,1656.095,1743.095,1675.057,1648.539,1585.114,1595.632,1592.784,1625.682,1741.925,1746.348,1724.352,1687.342,1671.886,1630.688,1591.013,1485.905,1416.143,1342.7,1284.348,1345.048,1348.464,1314.402,1277.417,1221.588,1243.068,1298.713,1336.56,1299.175,1288.913,1277.857,1312.989,1297.005,1241.33,1223.565,1176.413,1200.44,1249.333,1231.1,1180.636,1198.253,1197.684,1182.248,1131.58,1117.525,1124.905,1157.123,1088.388,1068.317,1095.655,1194.893,1246.312,1241.452,1259.755,1273.58,1337.429,1340.861,1326.618,1268.929,1240.293,1152.165,1192.648,1233.39,1231.063,1267.15,1245.25,1261.277,1235.1,1281.72,1317.045,1280.677,1283.189,1265.674,1332.809,1333.775,1325. ...

# %% [markdown]
# > Catatan:
# >
# > - **Strategi Penyetelan**: Kami menetapkan \( d = 1 \) (urutan differencing) dan melakukan pencarian grid pada nilai \( p \) dan \( q \) (kisaran 0 hingga 5) untuk menemukan model terbaik menggunakan RMSE (root mean squared error).
# >
# > - **Pemilihan Model Terbaik**: Model dengan RMSE terendah dipilih sebagai model ARIMA terbaik untuk peramalan dengan orde (0, 1, 1) dengan orde musiman (1, 1, 0, 12).
# >
# > - **Evaluasi**: Model ARIMA yang dipilih digunakan untuk meramalkan 64 bulan ke depan, dan akurasinya dievaluasi dengan menggunakan RMSE pada data uji dengan skor **191,5**. Secara keseluruhan, skor ini dan yang ditunjukkan pada diagram garis di atas berkinerja lebih buruk daripada ARIMA dasar.

# %% [markdown]
# #### **Prophet**

# %%
import random

df_train_prophet = df_train.rename(columns={'Date': 'ds', 'Price': 'y'})
df_test_prophet = df_test.rename(columns={'Date': 'ds', 'Price': 'y'})

param_grid = {
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5, 1.0, 2.5],
    'seasonality_prior_scale': [0.01, 0.1, 1.0, 10.0, 20.0],
    'holidays_prior_scale': [0.01, 0.1, 1.0, 10.0],
    'seasonality_mode': ['additive', 'multiplicative'],
    'yearly_seasonality': [True, False],
    'weekly_seasonality': [True, False],
    'daily_seasonality': [True, False],
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]

# Sample a random subset of the combinations (e.g., 20 random combinations)
random.seed(42)
sampled_params = random.sample(all_params, min(len(all_params), 100))  # Adjust sample size as needed

results = []

for params in sampled_params:
    try:
        prophet_model = Prophet(**params)
        prophet_model.fit(df_train_prophet)

        future = prophet_model.make_future_dataframe(periods=len(df_test), freq='D')

        prophet_forecast = prophet_model.predict(future)
        prophet_forecast_test = prophet_forecast[-len(df_test):]

        prophet_rmse = mean_squared_error(df_test_prophet['y'], prophet_forecast_test['yhat'], squared=False)

        results.append((params, prophet_rmse))
    except Exception as e:
        continue

sorted_results = sorted(results, key=lambda x: x[1])

sorted_results_df = pd.DataFrame(sorted_results, columns=['params', 'rmse'])

sorted_results_df.head()
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/wo3ci_70.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/9pxsc_s1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53344', 'data', 'file=/tmp/tmpbj4se_zr/wo3ci_70.json', 'init=/tmp/tmpbj4se_zr/9pxsc_s1.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelzmpu_npw/prophet_model-20240926085729.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/j7jg5afl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/pjmp44ue.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14127', 'data', 'file=/tmp/tmpbj4se_zr/j7jg5afl.json', 'init=/tmp/tmpbj4se_zr/pjmp44ue.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model449jd58n/prophet_model-20240926085730.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/g5148xh8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/57cptri1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53678', 'data', 'file=/tmp/tmpbj4se_zr/g5148xh8.json', 'init=/tmp/tmpbj4se_zr/57cptri1.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model6jbe4_pm/prophet_model-20240926085730.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/u5l6u7wa.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/m329nfh0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31951', 'data', 'file=/tmp/tmpbj4se_zr/u5l6u7wa.json', 'init=/tmp/tmpbj4se_zr/m329nfh0.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model0vsupuw4/prophet_model-20240926085730.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/q7p96dxl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/h_xzhao_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28189', 'data', 'file=/tmp/tmpbj4se_zr/q7p96dxl.json', 'init=/tmp/tmpbj4se_zr/h_xzhao_.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model12vynbyz/prophet_model-20240926085731.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/xpbv9i38.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/digt79g_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37659', 'data', 'file=/tmp/tmpbj4se_zr/xpbv9i38.json', 'init=/tmp/tmpbj4se_zr/digt79g_.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model5jhbn1k2/prophet_model-20240926085731.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/s53tdojn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/8pxmjv5l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68055', 'data', 'file=/tmp/tmpbj4se_zr/s53tdojn.json', 'init=/tmp/tmpbj4se_zr/8pxmjv5l.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelzcp4_05u/prophet_model-20240926085732.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/33vfusca.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/5givm53v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76379', 'data', 'file=/tmp/tmpbj4se_zr/33vfusca.json', 'init=/tmp/tmpbj4se_zr/5givm53v.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modeln8h_pw0w/prophet_model-20240926085732.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/nvrjdljb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/hbevj2de.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75166', 'data', 'file=/tmp/tmpbj4se_zr/nvrjdljb.json', 'init=/tmp/tmpbj4se_zr/hbevj2de.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelcamfa24s/prophet_model-20240926085732.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/c5j3fdoz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/prolbuq9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3762', 'data', 'file=/tmp/tmpbj4se_zr/c5j3fdoz.json', 'init=/tmp/tmpbj4se_zr/prolbuq9.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model6tfsbe6d/prophet_model-20240926085733.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/sfkjmt4p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/e0sxl3mk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89360', 'data', 'file=/tmp/tmpbj4se_zr/sfkjmt4p.json', 'init=/tmp/tmpbj4se_zr/e0sxl3mk.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelozyiktiu/prophet_model-20240926085733.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/n6pdp31g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/pgavxu7i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47931', 'data', 'file=/tmp/tmpbj4se_zr/n6pdp31g.json', 'init=/tmp/tmpbj4se_zr/pgavxu7i.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model_2c33v8e/prophet_model-20240926085734.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/z8pjnsg1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/uojawykd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98775', 'data', 'file=/tmp/tmpbj4se_zr/z8pjnsg1.json', 'init=/tmp/tmpbj4se_zr/uojawykd.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelhcuotwv_/prophet_model-20240926085735.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/41p1i_lb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/ld8aqtcb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18783', 'data', 'file=/tmp/tmpbj4se_zr/41p1i_lb.json', 'init=/tmp/tmpbj4se_zr/ld8aqtcb.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model29ylzevy/prophet_model-20240926085735.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/gvnqx3u0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/0zappea6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2052', 'data', 'file=/tmp/tmpbj4se_zr/gvnqx3u0.json', 'init=/tmp/tmpbj4se_zr/0zappea6.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model5v5j1tva/prophet_model-20240926085736.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/3hqcxnio.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/7a99m9x4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19499', 'data', 'file=/tmp/tmpbj4se_zr/3hqcxnio.json', 'init=/tmp/tmpbj4se_zr/7a99m9x4.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelx1l34gtu/prophet_model-20240926085736.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/n_508xny.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/1gobp57h.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46436', 'data', 'file=/tmp/tmpbj4se_zr/n_508xny.json', 'init=/tmp/tmpbj4se_zr/1gobp57h.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model5_j948xt/prophet_model-20240926085737.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/8n4jptxu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/7s8c8go4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46847', 'data', 'file=/tmp/tmpbj4se_zr/8n4jptxu.json', 'init=/tmp/tmpbj4se_zr/7s8c8go4.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model4mgoo5yx/prophet_model-20240926085738.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/sfdjddoz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/0hwpex5r.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17125', 'data', 'file=/tmp/tmpbj4se_zr/sfdjddoz.json', 'init=/tmp/tmpbj4se_zr/0hwpex5r.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model2pypncvz/prophet_model-20240926085739.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/5whdh63d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/o3kvnjxc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54603', 'data', 'file=/tmp/tmpbj4se_zr/5whdh63d.json', 'init=/tmp/tmpbj4se_zr/o3kvnjxc.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelomlovy79/prophet_model-20240926085739.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/98_h3re7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/jt09_wie.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54857', 'data', 'file=/tmp/tmpbj4se_zr/98_h3re7.json', 'init=/tmp/tmpbj4se_zr/jt09_wie.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelyyezxts_/prophet_model-20240926085740.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/c_2_uiey.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/v4i66lbe.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31910', 'data', 'file=/tmp/tmpbj4se_zr/c_2_uiey.json', 'init=/tmp/tmpbj4se_zr/v4i66lbe.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelve21adkd/prophet_model-20240926085740.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/d_ihwkvf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/fbz39ltc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87601', 'data', 'file=/tmp/tmpbj4se_zr/d_ihwkvf.json', 'init=/tmp/tmpbj4se_zr/fbz39ltc.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modeleql6qjst/prophet_model-20240926085741.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/fbs465kd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/3uvuppve.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92241', 'data', 'file=/tmp/tmpbj4se_zr/fbs465kd.json', 'init=/tmp/tmpbj4se_zr/3uvuppve.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model3pad0g7u/prophet_model-20240926085742.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/3o0s2jus.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/nktsbguc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33711', 'data', 'file=/tmp/tmpbj4se_zr/3o0s2jus.json', 'init=/tmp/tmpbj4se_zr/nktsbguc.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelt0jpx9ev/prophet_model-20240926085743.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/3xond15z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/_1ntfzmi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93348', 'data', 'file=/tmp/tmpbj4se_zr/3xond15z.json', 'init=/tmp/tmpbj4se_zr/_1ntfzmi.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model_weeclb8/prophet_model-20240926085743.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/t5v1ayh5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/_0qc_0j0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46675', 'data', 'file=/tmp/tmpbj4se_zr/t5v1ayh5.json', 'init=/tmp/tmpbj4se_zr/_0qc_0j0.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelzou1zbfb/prophet_model-20240926085744.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/_9_4ik7z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/0xdqeml2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93351', 'data', 'file=/tmp/tmpbj4se_zr/_9_4ik7z.json', 'init=/tmp/tmpbj4se_zr/0xdqeml2.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modeldmy3onds/prophet_model-20240926085744.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/6o9_8orb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/5_eclz7z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21843', 'data', 'file=/tmp/tmpbj4se_zr/6o9_8orb.json', 'init=/tmp/tmpbj4se_zr/5_eclz7z.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelxluvfokq/prophet_model-20240926085745.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/832sufcj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/mh4q6o7j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51714', 'data', 'file=/tmp/tmpbj4se_zr/832sufcj.json', 'init=/tmp/tmpbj4se_zr/mh4q6o7j.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelw5mtg5c0/prophet_model-20240926085746.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/i5vgd9y8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/s8m175mj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31296', 'data', 'file=/tmp/tmpbj4se_zr/i5vgd9y8.json', 'init=/tmp/tmpbj4se_zr/s8m175mj.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modeltac930ne/prophet_model-20240926085746.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/qyds355e.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/yy3tj5sp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66281', 'data', 'file=/tmp/tmpbj4se_zr/qyds355e.json', 'init=/tmp/tmpbj4se_zr/yy3tj5sp.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model9e_t6wxa/prophet_model-20240926085747.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/i3of27u2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/bcf5wzx6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=792', 'data', 'file=/tmp/tmpbj4se_zr/i3of27u2.json', 'init=/tmp/tmpbj4se_zr/bcf5wzx6.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model4rjvvga0/prophet_model-20240926085747.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/ls54crwt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/jsr32_25.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86335', 'data', 'file=/tmp/tmpbj4se_zr/ls54crwt.json', 'init=/tmp/tmpbj4se_zr/jsr32_25.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model5zv1yama/prophet_model-20240926085748.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/nr6cas5q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/1jtd6ncd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41818', 'data', 'file=/tmp/tmpbj4se_zr/nr6cas5q.json', 'init=/tmp/tmpbj4se_zr/1jtd6ncd.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model6wl1n88u/prophet_model-20240926085749.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/t30wnuwm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/sonk2o9c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45753', 'data', 'file=/tmp/tmpbj4se_zr/t30wnuwm.json', 'init=/tmp/tmpbj4se_zr/sonk2o9c.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelne429zcw/prophet_model-20240926085749.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/1v1w7_zi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/5z05ohjo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89248', 'data', 'file=/tmp/tmpbj4se_zr/1v1w7_zi.json', 'init=/tmp/tmpbj4se_zr/5z05ohjo.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modeltrc43hvi/prophet_model-20240926085750.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/geay232q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/vvx1in83.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80257', 'data', 'file=/tmp/tmpbj4se_zr/geay232q.json', 'init=/tmp/tmpbj4se_zr/vvx1in83.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelow6jr9w0/prophet_model-20240926085750.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/4yug8_u4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/lgk76lrc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68453', 'data', 'file=/tmp/tmpbj4se_zr/4yug8_u4.json', 'init=/tmp/tmpbj4se_zr/lgk76lrc.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelyuexev9p/prophet_model-20240926085750.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/1n364a2z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/j6ohb5qy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47624', 'data', 'file=/tmp/tmpbj4se_zr/1n364a2z.json', 'init=/tmp/tmpbj4se_zr/j6ohb5qy.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model3chq41rg/prophet_model-20240926085751.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/d45iik1z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/7hpnoo6c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67730', 'data', 'file=/tmp/tmpbj4se_zr/d45iik1z.json', 'init=/tmp/tmpbj4se_zr/7hpnoo6c.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelp57chsxo/prophet_model-20240926085752.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/y5w3mso3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/o21wpb3t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=97030', 'data', 'file=/tmp/tmpbj4se_zr/y5w3mso3.json', 'init=/tmp/tmpbj4se_zr/o21wpb3t.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelvib4l26n/prophet_model-20240926085752.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/mjmenost.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/ujpzmk6w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69650', 'data', 'file=/tmp/tmpbj4se_zr/mjmenost.json', 'init=/tmp/tmpbj4se_zr/ujpzmk6w.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelnx8tjgd5/prophet_model-20240926085753.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/o8wlu367.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/f2g282zs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49278', 'data', 'file=/tmp/tmpbj4se_zr/o8wlu367.json', 'init=/tmp/tmpbj4se_zr/f2g282zs.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model0owobo1_/prophet_model-20240926085754.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/csjnvir4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/03ujynmo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26391', 'data', 'file=/tmp/tmpbj4se_zr/csjnvir4.json', 'init=/tmp/tmpbj4se_zr/03ujynmo.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model03_o0hur/prophet_model-20240926085755.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/oza4awvd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/404kv7uk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59917', 'data', 'file=/tmp/tmpbj4se_zr/oza4awvd.json', 'init=/tmp/tmpbj4se_zr/404kv7uk.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modeljjlnfbvz/prophet_model-20240926085756.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/2tj8b0vq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/lorqq3nn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44408', 'data', 'file=/tmp/tmpbj4se_zr/2tj8b0vq.json', 'init=/tmp/tmpbj4se_zr/lorqq3nn.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelnvyjei2d/prophet_model-20240926085756.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/ztcp0s1d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/mji_n2cu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57500', 'data', 'file=/tmp/tmpbj4se_zr/ztcp0s1d.json', 'init=/tmp/tmpbj4se_zr/mji_n2cu.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model3h1va4et/prophet_model-20240926085757.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/s7wbjgcd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/er1am9y9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75643', 'data', 'file=/tmp/tmpbj4se_zr/s7wbjgcd.json', 'init=/tmp/tmpbj4se_zr/er1am9y9.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model3m7w68w6/prophet_model-20240926085758.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:57:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/pcf2flb9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/007577mb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49163', 'data', 'file=/tmp/tmpbj4se_zr/pcf2flb9.json', 'init=/tmp/tmpbj4se_zr/007577mb.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model1waa4thd/prophet_model-20240926085758.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:57:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/kd1ign8p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/6jo2u0nt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79865', 'data', 'file=/tmp/tmpbj4se_zr/kd1ign8p.json', 'init=/tmp/tmpbj4se_zr/6jo2u0nt.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model_sgbca4h/prophet_model-20240926085800.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/q4lmutqi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/883lbbnb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16902', 'data', 'file=/tmp/tmpbj4se_zr/q4lmutqi.json', 'init=/tmp/tmpbj4se_zr/883lbbnb.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelc7csn084/prophet_model-20240926085800.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/hdhmwhca.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/e5ztrb8v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30218', 'data', 'file=/tmp/tmpbj4se_zr/hdhmwhca.json', 'init=/tmp/tmpbj4se_zr/e5ztrb8v.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model1g6nz64m/prophet_model-20240926085800.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/zbgbzum7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/wxw_tm5_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27949', 'data', 'file=/tmp/tmpbj4se_zr/zbgbzum7.json', 'init=/tmp/tmpbj4se_zr/wxw_tm5_.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model_hpdmcf6/prophet_model-20240926085801.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/hkc3enxv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/4qg93vup.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3257', 'data', 'file=/tmp/tmpbj4se_zr/hkc3enxv.json', 'init=/tmp/tmpbj4se_zr/4qg93vup.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelx7bl3qm3/prophet_model-20240926085802.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/ycai89kd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/fic295xd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36679', 'data', 'file=/tmp/tmpbj4se_zr/ycai89kd.json', 'init=/tmp/tmpbj4se_zr/fic295xd.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelwlmc_ook/prophet_model-20240926085802.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/jt_4uvma.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/8oqcvvae.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54245', 'data', 'file=/tmp/tmpbj4se_zr/jt_4uvma.json', 'init=/tmp/tmpbj4se_zr/8oqcvvae.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelyhik24l9/prophet_model-20240926085803.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/b0ndx0o1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/2sipb23s.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69748', 'data', 'file=/tmp/tmpbj4se_zr/b0ndx0o1.json', 'init=/tmp/tmpbj4se_zr/2sipb23s.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelm_3f3m65/prophet_model-20240926085803.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/u8unq_76.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/fgszom9q.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53189', 'data', 'file=/tmp/tmpbj4se_zr/u8unq_76.json', 'init=/tmp/tmpbj4se_zr/fgszom9q.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model5okdtt5q/prophet_model-20240926085804.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/u5g8x8p9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/sx7zob7w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76131', 'data', 'file=/tmp/tmpbj4se_zr/u5g8x8p9.json', 'init=/tmp/tmpbj4se_zr/sx7zob7w.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelnsw5v6v1/prophet_model-20240926085804.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/su7c5mk6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/omm8w79z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8988', 'data', 'file=/tmp/tmpbj4se_zr/su7c5mk6.json', 'init=/tmp/tmpbj4se_zr/omm8w79z.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model01ovue6p/prophet_model-20240926085806.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/b1jxsswz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/al5pej2g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14423', 'data', 'file=/tmp/tmpbj4se_zr/b1jxsswz.json', 'init=/tmp/tmpbj4se_zr/al5pej2g.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modeljmf3mc1l/prophet_model-20240926085807.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/3jvpichv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/qr9xqv3_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89813', 'data', 'file=/tmp/tmpbj4se_zr/3jvpichv.json', 'init=/tmp/tmpbj4se_zr/qr9xqv3_.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelxop8z4zq/prophet_model-20240926085807.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/m2eis8y2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/tdw0tu6f.json
# DEBUG:cmdstanpy:idx 0
# ...
# 08:58:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/opi_ns2g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/hg2o8ys1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57354', 'data', 'file=/tmp/tmpbj4se_zr/opi_ns2g.json', 'init=/tmp/tmpbj4se_zr/hg2o8ys1.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model2b0jr23l/prophet_model-20240926085817.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/vmlifvd5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/0yp1_vuj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86405', 'data', 'file=/tmp/tmpbj4se_zr/vmlifvd5.json', 'init=/tmp/tmpbj4se_zr/0yp1_vuj.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model979i98e2/prophet_model-20240926085817.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/r1mhe21z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/svqv1rza.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71306', 'data', 'file=/tmp/tmpbj4se_zr/r1mhe21z.json', 'init=/tmp/tmpbj4se_zr/svqv1rza.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelkd8ld2a8/prophet_model-20240926085818.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/qk14ace5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/vf32bcp2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61875', 'data', 'file=/tmp/tmpbj4se_zr/qk14ace5.json', 'init=/tmp/tmpbj4se_zr/vf32bcp2.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelcbx_xm_w/prophet_model-20240926085818.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/8wkv4rml.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/w0jcpzdz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9141', 'data', 'file=/tmp/tmpbj4se_zr/8wkv4rml.json', 'init=/tmp/tmpbj4se_zr/w0jcpzdz.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model9y_f6eom/prophet_model-20240926085818.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/zg41ig5c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/qe4toqzb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11027', 'data', 'file=/tmp/tmpbj4se_zr/zg41ig5c.json', 'init=/tmp/tmpbj4se_zr/qe4toqzb.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelt5ons36h/prophet_model-20240926085819.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/isn0kyty.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/nhry87j7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4494', 'data', 'file=/tmp/tmpbj4se_zr/isn0kyty.json', 'init=/tmp/tmpbj4se_zr/nhry87j7.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelrmkmzoo6/prophet_model-20240926085819.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/lod0mj1y.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/0rhqhmof.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96962', 'data', 'file=/tmp/tmpbj4se_zr/lod0mj1y.json', 'init=/tmp/tmpbj4se_zr/0rhqhmof.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelesj8kph9/prophet_model-20240926085821.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/x0qdt8ih.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/0seuc0iv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95432', 'data', 'file=/tmp/tmpbj4se_zr/x0qdt8ih.json', 'init=/tmp/tmpbj4se_zr/0seuc0iv.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model058f5m07/prophet_model-20240926085821.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/dk37dkzr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/xpwkqn8f.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64291', 'data', 'file=/tmp/tmpbj4se_zr/dk37dkzr.json', 'init=/tmp/tmpbj4se_zr/xpwkqn8f.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model6sh__t27/prophet_model-20240926085822.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/6gho8lml.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/c91a173w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6993', 'data', 'file=/tmp/tmpbj4se_zr/6gho8lml.json', 'init=/tmp/tmpbj4se_zr/c91a173w.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modeluv8cl5y4/prophet_model-20240926085823.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/yiv9881q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/a9kl3sud.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27128', 'data', 'file=/tmp/tmpbj4se_zr/yiv9881q.json', 'init=/tmp/tmpbj4se_zr/a9kl3sud.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelplpgykm5/prophet_model-20240926085823.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/1joqgc2e.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/4_5x0drz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44911', 'data', 'file=/tmp/tmpbj4se_zr/1joqgc2e.json', 'init=/tmp/tmpbj4se_zr/4_5x0drz.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modeln2foholg/prophet_model-20240926085823.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/kj2b76ax.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/0iyy88rl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55483', 'data', 'file=/tmp/tmpbj4se_zr/kj2b76ax.json', 'init=/tmp/tmpbj4se_zr/0iyy88rl.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelbieadgxm/prophet_model-20240926085824.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/tprwwunm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/bu8bpphw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33331', 'data', 'file=/tmp/tmpbj4se_zr/tprwwunm.json', 'init=/tmp/tmpbj4se_zr/bu8bpphw.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelyr_woerw/prophet_model-20240926085824.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/s050g86k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/ni474kan.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76036', 'data', 'file=/tmp/tmpbj4se_zr/s050g86k.json', 'init=/tmp/tmpbj4se_zr/ni474kan.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelna0700ng/prophet_model-20240926085825.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/v3d5gdd8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/dpkkgp0r.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85253', 'data', 'file=/tmp/tmpbj4se_zr/v3d5gdd8.json', 'init=/tmp/tmpbj4se_zr/dpkkgp0r.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modeljq85xx02/prophet_model-20240926085825.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/6x25vbqr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/pawvuzs8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26286', 'data', 'file=/tmp/tmpbj4se_zr/6x25vbqr.json', 'init=/tmp/tmpbj4se_zr/pawvuzs8.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_model05tdn0qd/prophet_model-20240926085826.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/uudtjz_4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/0uzlwex0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5843', 'data', 'file=/tmp/tmpbj4se_zr/uudtjz_4.json', 'init=/tmp/tmpbj4se_zr/0uzlwex0.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelrspmdn5c/prophet_model-20240926085826.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/15lk4n5v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/57sstfhq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99046', 'data', 'file=/tmp/tmpbj4se_zr/15lk4n5v.json', 'init=/tmp/tmpbj4se_zr/57sstfhq.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelh8_8otan/prophet_model-20240926085827.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#                                               params        rmse
# 0  {'changepoint_prior_scale': 2.5, 'seasonality_...  212.367434
# 1  {'changepoint_prior_scale': 2.5, 'seasonality_...  216.080274
# 2  {'changepoint_prior_scale': 1.0, 'seasonality_...  218.947130
# 3  {'changepoint_prior_scale': 0.1, 'seasonality_...  231.951519
# 4  {'changepoint_prior_scale': 2.5, 'seasonality_...  232.106489

# %% [markdown]
# > Catatan:
# >
# > - **Bagaimana Prophet Bekerja**: Prophet menguraikan deret waktu menjadi tren, musiman, dan hari libur, secara otomatis mendeteksi pergeseran tren dan pola musiman tanpa transformasi manual.
# >
# > - **Perbedaan Utama dari ARIMA/SARIMA**: Prophet dapat menangani data non-stasioner dan tidak memerlukan pembedaan seperti ARIMA/SARIMA. Prophet secara langsung memodelkan tren dan musiman, sementara ARIMA/SARIMA berfokus pada autoregressive dan moving average.
# >
# > - **Penjelasan setiap hyperparam**:
# > - **`changepoint_prior_scale`**: Mengontrol fleksibilitas tren. Nilai yang lebih tinggi memungkinkan tren untuk beradaptasi lebih cepat terhadap perubahan, sementara nilai yang lebih rendah membuat tren lebih halus.
# >
# > - **`seasonality_prior_scale`**: Mengatur fleksibilitas komponen musiman. Nilai yang lebih tinggi memungkinkan lebih banyak variasi dalam musiman, sementara nilai yang lebih rendah membuat pola musiman lebih stabil.
# >
# > - **`holidays_prior_scale`**: Mengontrol fleksibilitas efek hari libur. Nilai yang lebih tinggi memungkinkan efek hari libur lebih bervariasi, sementara nilai yang lebih rendah membuat efek hari libur lebih dibatasi.
# >
# > - **`seasonality_mode`**: Menentukan apakah musiman bersifat **additive** (menambah tren) atau **multiplicative** (bervariasi secara proporsional dengan tren).
# >
# > - **`musiman_tahunan`**: Mengaktifkan atau menonaktifkan musiman tahunan dalam model.
# >
# > - **`musiman_mingguan`**: Mengaktifkan atau menonaktifkan musiman mingguan dalam model.
# >
# > - **`musiman_harian`**: Mengaktifkan atau menonaktifkan musiman harian dalam model.

# %%
best_params = sorted_results_df.iloc[0]['params']

prophet_model = Prophet(
    changepoint_prior_scale=best_params['changepoint_prior_scale'],
    seasonality_prior_scale=best_params['seasonality_prior_scale'],
    holidays_prior_scale=best_params['holidays_prior_scale'],
    seasonality_mode=best_params['seasonality_mode'],
    yearly_seasonality=best_params['yearly_seasonality'],
    weekly_seasonality=best_params['weekly_seasonality'],
    daily_seasonality=best_params['daily_seasonality']
)

prophet_model.fit(df_train_prophet)

future = prophet_model.make_future_dataframe(periods=len(df_test), freq='D')

prophet_forecast = prophet_model.predict(future)
prophet_forecast_test = prophet_forecast[-len(df_test):]['yhat']
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/w42ex7nk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbj4se_zr/uu681f3b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25013', 'data', 'file=/tmp/tmpbj4se_zr/w42ex7nk.json', 'init=/tmp/tmpbj4se_zr/uu681f3b.json', 'output', 'file=/tmp/tmpbj4se_zr/prophet_modelrfhe77oj/prophet_model-20240926085827.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:58:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:58:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
month=list(df_test['Date'].unique())

df_forecast_prophet=pd.DataFrame({'Date':month,'Price':prophet_forecast_test})
df_forecast_prophet
# Out:
#         Date        Price
# 88   2013-06  1478.478790
# 89   2013-07  1455.082304
# 90   2013-08  1415.246190
# 91   2013-09  1377.064324
# 92   2013-10  1343.402126
# ..       ...          ...
# 147  2018-05  1493.805741
# 148  2018-06  1555.894578
# 149  2018-07  1635.248505
# 150  2018-08  1680.407024
# 151  2018-09  1764.318995
#
# [64 rows x 2 columns]

# %%
import plotly.graph_objects as go

fig = go.Figure([go.Scatter(name='Actual', x=df['Date'], y=df['Price'], mode='markers')])

fig.add_trace(go.Scatter(name='Forecast', x=df_forecast_prophet['Date'], y=df_forecast_prophet['Price']))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="50ce2825-1b6e-4125-b730-66f6b1664132" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50ce2825-1b6e-4125-b730-66f6b1664132")) {                    Plotly.newPlot(                        "50ce2825-1b6e-4125-b730-66f6b1664132",                        [{"mode":"markers","name":"Actual","x":["2003-02","2003-03","2003-04","2003-05","2003-06","2003-07","2003-08","2003-09","2003-10","2003-11","2003-12","2004-01","2004-02","2004-03","2004-04","2004-05","2004-06","2004-07","2004-08","2004-09","2004-10","2004-11","2004-12","2005-01","2005-02","2005-03","2005-04","2005-05","2005-06","2005-07","2005-08","2005-09","2005-10","2005-11","2005-12","2006-01","2006-02","2006-03","2006-04","2006-05","2006-06","2006-07","2006-08","2006-09","2006-10","2006-11","2006-12","2007-01","2007-02","2007-03","2007-04","2007-05","2007-06","2007-07","2007-08","2007-09","2007-10","2007-11","2007-12","2008-01","2008-02","2008-03","2008-04","2008-05","2008-06","2008-07","2008-08","2008-09","2008-10","2008-11","2008-12","2009-01","2009-02","2009-03","2009-04","2009-05","2009-06","2009-07","2009-08","2009-09","2009-10","2009-11","2009-12","2010-01","2010-02","2010-03","2010-04","2010-05","2010-06","2010-07","2010-08","2010-09","2010-10","2010-11","2010-12","2011-01","2011-02","2011-03","2011-04","2011-05","2011-06","2011-07","2011-08","2011-09","2011-10","2011-11","2011-12","2012-01","2012-02","2012-03","2012-04","2012-05","2012-06","2012-07","2012-08","2012-09","2012-10","2012-11","2012-12","2013-01","2013-02","2013-03","2013-04","2013-05","2013-06","2013-07","2013-08","2013-09","2013-10","2013-11","2013-12","2014-01","2014-02","2014-03","2014-04","2014-05","2014-06","2014-07","2014-08","2014-09","2014-10","2014-11","2014-12","2015-01","2015-02","2015-03","2015-04","2015-05","2015-06","2015-07","2015-08","2015-09","2015-10","2015-11","2015-12","2016-01","2016-02","2016-03","2016-04","2016-05","2016-06","2016-07","2016-08","2016-09","2016-10","2016-11","2016-12","2017-01","2017-02","2017-03","2017-04","2017-05","2017-06","2017-07","2017-08","2017-09","2017-10","2017-11","2017-12","2018-01","2018-02","2018-03","2018-04","2018-05","2018-06","2018-07","2018-08","2018-09"],"y":[359.575,341.564,328.208,355.405,356.912,350.765,358.993,378.859,379.093,390.2,407.674,414.495,404.73,405.976,404.85,383.953,391.78,398.441,400.133,405.402,420.21,439.059,442.974,424.08,423.43,434.355,429.14,422.903,430.302,424.745,437.773,455.936,470.107,476.668,509.423,549.433,555.518,557.215,611.853,676.769,597.898,633.093,631.557,600.15,586.648,626.825,629.513,630.352,665.103,655.891,680.008,668.31,655.714,665.266,664.53,710.645,754.48,808.311,803.618,887.784,924.283,971.055,911.6,889.125,889.536,941.167,840.388,824.92,812.815,757.85,819.94,857.726,939.763,925.989,892.663,926.855,947.807,934.272,949.5,996.443,1043.511,1126.119,1135.012,1119.575,1095.8,1115.554,1148.475,1204.321,1232.382,1196.0,1213.464,1271.461,1343.19,1371.784,1393.512,1360.475,1371.313,1422.848,1474.431,1512.188,1528.38,1568.526,1759.5,1780.648,1667.893,1735.977,1652.725,1656.095,1743.095,1675.057,1648.539,1585.114,1595.632,1592.784,1625.682,1741.925,1746.348,1724.352,1687.342,1671.886,1630.688,1591.013,1485.905,1416.143,1342.7,1284.348,1345.048,1348.464,1314.402,1277.417,1221.588,1243.068,1298.713,1336.56,1299.175,1288.913,1277.857,1312.989,1297.005,1241.33,1223.565,1176.413,1200.44,1249.333,1231.1,1180.636,1198.253,1197.684,1182.248,1131.58,1117.525,1124.905,1157.123,1088.388,1068.317,1095.655,1194.893,1246.312,1241.452,1259.755,1273.58,1337.429,1340.861,1326.618,1268.929,1240.293,1152.165,1192.648,1233.39,1231.063,1267.15,1245.25,1261.277,1235.1,1281.72,1317.045,1280.677,1283.189,1265.674,1332.809,1333.775,1325. ...

# %% [markdown]
# > Catatan:
# >
# > - **Strategi Penyetelan**: Kami melakukan pencarian grid di berbagai hiperparameter Prophet termasuk `changepoint_prior_scale`, `seasonality_prior_scale`, dan `holidays_prior_scale`, dengan menguji 100 kombinasi acak untuk menemukan model terbaik dengan menggunakan RMSE (root mean squared error).
# >
# > - **Pemilihan Model Terbaik**: Model dengan RMSE terendah dipilih sebagai model Prophet terbaik untuk peramalan, dengan parameter seperti `changepoint_prior_scale` diatur ke 2,5 dan `seasonality_prior_scale` diatur ke 20,0.
# >
# > - **Evaluasi**: Model Prophet yang dipilih digunakan untuk meramalkan nilai masa depan, dan akurasinya dievaluasi dengan menggunakan RMSE pada data uji. Performa model divisualisasikan dan dibandingkan dengan metode lain, memberikan wawasan tentang tren dan efek musiman. Secara keseluruhan, model ini menunjukkan kinerja yang buruk dan tidak dapat menangkap tren utama.

# %% [markdown]
# #### **Model Comparison**

# %%
import plotly.graph_objects as go

fig = go.Figure([go.Scatter(name='Actual', x=df['Date'], y=df['Price'], mode='markers')])

fig.add_trace(go.Scatter(name='Prophet', x=df_forecast_prophet['Date'], y=df_forecast_prophet['Price']))
fig.add_trace(go.Scatter(name='ARIMA', x=df_forecast_arima['Date'], y=df_forecast_arima['Price']))
fig.add_trace(go.Scatter(name='SARIMA', x=df_forecast_sarima['Date'], y=df_forecast_sarima['Price']))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="60ec612e-00c7-40dc-8c3d-3d43b964afff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60ec612e-00c7-40dc-8c3d-3d43b964afff")) {                    Plotly.newPlot(                        "60ec612e-00c7-40dc-8c3d-3d43b964afff",                        [{"mode":"markers","name":"Actual","x":["2003-02","2003-03","2003-04","2003-05","2003-06","2003-07","2003-08","2003-09","2003-10","2003-11","2003-12","2004-01","2004-02","2004-03","2004-04","2004-05","2004-06","2004-07","2004-08","2004-09","2004-10","2004-11","2004-12","2005-01","2005-02","2005-03","2005-04","2005-05","2005-06","2005-07","2005-08","2005-09","2005-10","2005-11","2005-12","2006-01","2006-02","2006-03","2006-04","2006-05","2006-06","2006-07","2006-08","2006-09","2006-10","2006-11","2006-12","2007-01","2007-02","2007-03","2007-04","2007-05","2007-06","2007-07","2007-08","2007-09","2007-10","2007-11","2007-12","2008-01","2008-02","2008-03","2008-04","2008-05","2008-06","2008-07","2008-08","2008-09","2008-10","2008-11","2008-12","2009-01","2009-02","2009-03","2009-04","2009-05","2009-06","2009-07","2009-08","2009-09","2009-10","2009-11","2009-12","2010-01","2010-02","2010-03","2010-04","2010-05","2010-06","2010-07","2010-08","2010-09","2010-10","2010-11","2010-12","2011-01","2011-02","2011-03","2011-04","2011-05","2011-06","2011-07","2011-08","2011-09","2011-10","2011-11","2011-12","2012-01","2012-02","2012-03","2012-04","2012-05","2012-06","2012-07","2012-08","2012-09","2012-10","2012-11","2012-12","2013-01","2013-02","2013-03","2013-04","2013-05","2013-06","2013-07","2013-08","2013-09","2013-10","2013-11","2013-12","2014-01","2014-02","2014-03","2014-04","2014-05","2014-06","2014-07","2014-08","2014-09","2014-10","2014-11","2014-12","2015-01","2015-02","2015-03","2015-04","2015-05","2015-06","2015-07","2015-08","2015-09","2015-10","2015-11","2015-12","2016-01","2016-02","2016-03","2016-04","2016-05","2016-06","2016-07","2016-08","2016-09","2016-10","2016-11","2016-12","2017-01","2017-02","2017-03","2017-04","2017-05","2017-06","2017-07","2017-08","2017-09","2017-10","2017-11","2017-12","2018-01","2018-02","2018-03","2018-04","2018-05","2018-06","2018-07","2018-08","2018-09"],"y":[359.575,341.564,328.208,355.405,356.912,350.765,358.993,378.859,379.093,390.2,407.674,414.495,404.73,405.976,404.85,383.953,391.78,398.441,400.133,405.402,420.21,439.059,442.974,424.08,423.43,434.355,429.14,422.903,430.302,424.745,437.773,455.936,470.107,476.668,509.423,549.433,555.518,557.215,611.853,676.769,597.898,633.093,631.557,600.15,586.648,626.825,629.513,630.352,665.103,655.891,680.008,668.31,655.714,665.266,664.53,710.645,754.48,808.311,803.618,887.784,924.283,971.055,911.6,889.125,889.536,941.167,840.388,824.92,812.815,757.85,819.94,857.726,939.763,925.989,892.663,926.855,947.807,934.272,949.5,996.443,1043.511,1126.119,1135.012,1119.575,1095.8,1115.554,1148.475,1204.321,1232.382,1196.0,1213.464,1271.461,1343.19,1371.784,1393.512,1360.475,1371.313,1422.848,1474.431,1512.188,1528.38,1568.526,1759.5,1780.648,1667.893,1735.977,1652.725,1656.095,1743.095,1675.057,1648.539,1585.114,1595.632,1592.784,1625.682,1741.925,1746.348,1724.352,1687.342,1671.886,1630.688,1591.013,1485.905,1416.143,1342.7,1284.348,1345.048,1348.464,1314.402,1277.417,1221.588,1243.068,1298.713,1336.56,1299.175,1288.913,1277.857,1312.989,1297.005,1241.33,1223.565,1176.413,1200.44,1249.333,1231.1,1180.636,1198.253,1197.684,1182.248,1131.58,1117.525,1124.905,1157.123,1088.388,1068.317,1095.655,1194.893,1246.312,1241.452,1259.755,1273.58,1337.429,1340.861,1326.618,1268.929,1240.293,1152.165,1192.648,1233.39,1231.063,1267.15,1245.25,1261.277,1235.1,1281.72,1317.045,1280.677,1283.189,1265.674,1332.809,1333.775,1325. ...

# %% [markdown]
# > Catatan:
# >
# > - **Kinerja Prakiraan**: Model **Prophet** menangkap tren awal tetapi gagal menangkap tren jangka panjang dan terlalu tinggi memperkirakan nilai masa depan, terutama setelah tahun 2015, sehingga menunjukkan kinerja yang buruk di periode selanjutnya.
# >
# > - **SARIMA**: Model ini berkinerja buruk dan menciptakan pola yang konstan sepanjang prediksi. Model ini gagal menangkap tren apa pun.
# >
# > - **Model Berkinerja Terbaik**: Secara keseluruhan, **ARIMA** menunjukkan kecocokan yang lebih baik pada periode pengujian, memiliki RMSE paling kecil di sekitar **65,9**, dan dapat menangkap tren dengan baik dari waktu ke waktu.

# %% [markdown]
# #### **Final Result Forcast**

# %%
# Concatenating train and test DataFrames along the rows
df_final = pd.concat([df_train, df_test])
df_final = df_final[["Date","Price"]]
df_final
# Out:
#         Date     Price
# 673  2006-02   555.518
# 674  2006-03   557.215
# 675  2006-04   611.853
# 676  2006-05   676.769
# 677  2006-06   597.898
# ..       ...       ...
# 820  2018-05  1303.618
# 821  2018-06  1282.126
# 822  2018-07  1238.064
# 823  2018-08  1201.859
# 824  2018-09  1199.198
#
# [152 rows x 2 columns]

# %%
from statsmodels.tsa.arima.model import ARIMA
model=ARIMA(df_final['Price'],order=(6,1,9))

model_fit=model.fit()

forecast_length=24
forecast_result=model_fit.forecast(forecast_length)

# %% [markdown]
# > Catatan:
# >
# > - **Prediksi**: Kami akan memilih model dengan performa terbaik dari ketiganya (Tuned ARIMA) dan meramalkan 2 tahun ke depan.

# %%
import pandas as pd

last_date = pd.to_datetime(df_test['Date'].max())

month = pd.date_range(last_date + pd.DateOffset(months=1), periods=24, freq='M').strftime('%Y-%m').tolist()

df_forecast_final = pd.DataFrame({'Date': month, 'Price': forecast_result})
df_forecast_final.head()
# Out:
#         Date        Price
# 152  2018-10  1183.045524
# 153  2018-11  1171.640052
# 154  2018-12  1169.644143
# 155  2019-01  1177.909550
# 156  2019-02  1199.004246

# %%
import plotly.graph_objects as go

fig = go.Figure([go.Scatter(name='Actual', x=df_final['Date'], y=df_final['Price'], mode='markers')])

fig.add_trace(go.Scatter(name='Forecast', x=df_forecast_final['Date'], y=df_forecast_final['Price']))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="999a7dac-8698-4098-ac1e-784144a8aa00" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("999a7dac-8698-4098-ac1e-784144a8aa00")) {                    Plotly.newPlot(                        "999a7dac-8698-4098-ac1e-784144a8aa00",                        [{"mode":"markers","name":"Actual","x":["2006-02","2006-03","2006-04","2006-05","2006-06","2006-07","2006-08","2006-09","2006-10","2006-11","2006-12","2007-01","2007-02","2007-03","2007-04","2007-05","2007-06","2007-07","2007-08","2007-09","2007-10","2007-11","2007-12","2008-01","2008-02","2008-03","2008-04","2008-05","2008-06","2008-07","2008-08","2008-09","2008-10","2008-11","2008-12","2009-01","2009-02","2009-03","2009-04","2009-05","2009-06","2009-07","2009-08","2009-09","2009-10","2009-11","2009-12","2010-01","2010-02","2010-03","2010-04","2010-05","2010-06","2010-07","2010-08","2010-09","2010-10","2010-11","2010-12","2011-01","2011-02","2011-03","2011-04","2011-05","2011-06","2011-07","2011-08","2011-09","2011-10","2011-11","2011-12","2012-01","2012-02","2012-03","2012-04","2012-05","2012-06","2012-07","2012-08","2012-09","2012-10","2012-11","2012-12","2013-01","2013-02","2013-03","2013-04","2013-05","2013-06","2013-07","2013-08","2013-09","2013-10","2013-11","2013-12","2014-01","2014-02","2014-03","2014-04","2014-05","2014-06","2014-07","2014-08","2014-09","2014-10","2014-11","2014-12","2015-01","2015-02","2015-03","2015-04","2015-05","2015-06","2015-07","2015-08","2015-09","2015-10","2015-11","2015-12","2016-01","2016-02","2016-03","2016-04","2016-05","2016-06","2016-07","2016-08","2016-09","2016-10","2016-11","2016-12","2017-01","2017-02","2017-03","2017-04","2017-05","2017-06","2017-07","2017-08","2017-09","2017-10","2017-11","2017-12","2018-01","2018-02","2018-03","2018-04","2018-05","2018-06","2018-07","2018-08","2018-09"],"y":[555.518,557.215,611.853,676.769,597.898,633.093,631.557,600.15,586.648,626.825,629.513,630.352,665.103,655.891,680.008,668.31,655.714,665.266,664.53,710.645,754.48,808.311,803.618,887.784,924.283,971.055,911.6,889.125,889.536,941.167,840.388,824.92,812.815,757.85,819.94,857.726,939.763,925.989,892.663,926.855,947.807,934.272,949.5,996.443,1043.511,1126.119,1135.012,1119.575,1095.8,1115.554,1148.475,1204.321,1232.382,1196.0,1213.464,1271.461,1343.19,1371.784,1393.512,1360.475,1371.313,1422.848,1474.431,1512.188,1528.38,1568.526,1759.5,1780.648,1667.893,1735.977,1652.725,1656.095,1743.095,1675.057,1648.539,1585.114,1595.632,1592.784,1625.682,1741.925,1746.348,1724.352,1687.342,1671.886,1630.688,1591.013,1485.905,1416.143,1342.7,1284.348,1345.048,1348.464,1314.402,1277.417,1221.588,1243.068,1298.713,1336.56,1299.175,1288.913,1277.857,1312.989,1297.005,1241.33,1223.565,1176.413,1200.44,1249.333,1231.1,1180.636,1198.253,1197.684,1182.248,1131.58,1117.525,1124.905,1157.123,1088.388,1068.317,1095.655,1194.893,1246.312,1241.452,1259.755,1273.58,1337.429,1340.861,1326.618,1268.929,1240.293,1152.165,1192.648,1233.39,1231.063,1267.15,1245.25,1261.277,1235.1,1281.72,1317.045,1280.677,1283.189,1265.674,1332.809,1333.775,1325.562,1335.332,1303.618,1282.126,1238.064,1201.859,1199.198],"type":"scatter"},{"name":"Forecast","x":["2018-10","2018-11","2018-12","2019-01","2019-02","2019-03","2019-04","2019-05","2019-06","2019-07","2019-08","2019-09","2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09"],"y":[1183.045523820113,1171.640052425834,1169.644142982843,1177.909550358179,1199.0042461381927,1201.0186231438643,1197.3450434666552,1169.8343566507006,1160.083207330367,1150.73964501132,1161.9371018683848,1158.926868165035,1150.5944507745826,1129.4156476257167,1113.8230942762916,1112.6272532758 ...

# %% [markdown]
# > Catatan:
# >
# > - **Final Forecast Performance**: Lineplot akhir di atas menunjukkan prediksi 2 tahun ke depan untuk harga emas berdasarkan hasil pelatihan model ARIMA yang telah disetel. Ini menunjukkan tren penurunan harga emas.

# %% [markdown]
# ## **Conclusion & Recommendation**

# %% [markdown]
# ### **Conclusion**
# Di antara ketiga model (ARIMA, SARIMA, dan Prophet), model ARIMA memberikan performa terbaik dengan RMSE 65,9, menjadikannya model yang paling akurat untuk meramalkan harga emas di masa depan. Model ini dapat menangkap perubahan tren dari waktu ke waktu secara signifikan sehingga dapat meramalkan harga dengan akurasi yang lebih tinggi.
#
# ### **Recommendation**
# Perusahaan sebaiknya menggunakan model ARIMA untuk memprediksi harga emas karena akurasinya yang superior. Untuk perbaikan yang berkelanjutan, disarankan untuk melakukan penyetelan dan pemantauan lebih lanjut terhadap performa model dalam merespons perubahan kondisi pasar.
